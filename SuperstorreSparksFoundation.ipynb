# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/SampleSuperstore.csv')
dataset
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# I want to get the mean profit
mean_profit = df.Profit.mean()
mean_profit
# Out:
# 28.65689630778467

# %%
c = df.groupby("State")["Profit"].sum()
plt.boxplot(c)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7da53be889a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7da53be88ee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7da53be886a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7da53be89420>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7da53be896c0>],
#  'means': []}

# %%
sum(df['Profit']/len(df))
# Out:
# 28.656896307784606

# %%
df = dataset[dataset['Profit'] <= 0][['Region','State', 'City', 'Profit']].groupby(['Region', 'State'])['Profit'].sum().to_frame().reset_index()
df.sort_values(by=['Region', 'Profit'])
# Out:
#      Region           State      Profit
# 4   Central           Texas -36813.1875
# 0   Central        Illinois -19501.6975
# 1   Central         Indiana      0.0000
# 2   Central        Michigan      0.0000
# 3   Central       Minnesota      0.0000
# 12     East            Ohio -21750.0002
# 13     East    Pennsylvania -21602.8515
# 11     East        New York  -5031.1378
# 8      East   Massachusetts   -566.2617
# 14     East    Rhode Island   -230.1678
# 9      East   New Hampshire   -105.3164
# 6      East        Delaware    -85.8963
# 15     East   West Virginia    -76.9536
# 7      East        Maryland    -71.1170
# 10     East      New Jersey    -51.2906
# 5      East     Connecticut    -19.6146
# 20    South  North Carolina -11557.9854
# 17    South         Florida  -8689.8295
# 21    South       Tennessee  -7257.0174
# 16    South         Alabama      0.0000
# 18    South        Kentucky      0.0000
# 19    South     Mississippi      0.0000
# ...

# %%
df2 = dataset[dataset['Profit'] <= 0][['Category', 'Sub-Category', 'Profit']].groupby(['Category', 'Sub-Category'])['Profit'].sum().to_frame().reset_index()
df2
# Out:
#            Category Sub-Category      Profit
# 0         Furniture    Bookcases -12152.2060
# 1         Furniture       Chairs  -9880.8413
# 2         Furniture  Furnishings  -6490.9134
# 3         Furniture       Tables -32412.1483
# 4   Office Supplies   Appliances  -8629.6412
# 5   Office Supplies      Binders -38510.4964
# 6   Office Supplies    Fasteners    -33.1952
# 7   Office Supplies      Storage  -6426.3038
# 8   Office Supplies     Supplies  -3015.6219
# 9        Technology  Accessories   -930.6265
# 10       Technology     Machines -30118.6682
# 11       Technology       Phones  -7530.6235

# %%
# discount histogram
plt.hist(dataset['Discount'])
plt.title('Distribution of Discount')
plt.xlabel('Discount')
plt.ylabel('Frequency')
plt.show()
